# %% [markdown]
# # Imports and setup

# %%
import torch  
from torchvision.datasets import ImageFolder
from torchvision.transforms import Resize, ToTensor, Compose
from torchvision.transforms.functional import to_pil_image
from torch.utils.data import DataLoader, random_split
import matplotlib.pyplot as plt
from random import random
from PIL import Image
import pandas as pd
import os
from pathlib import Path

# %% [markdown]
# ## Resize image and convert into a tensor

# %%
transform = Compose([
    Resize((224, 224)),
    ToTensor()
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 transform = Compose([
#       2     Resize((224, 224)),
#       3     ToTensor()
#       4 ])
#
# NameError: name 'Compose' is not defined

# %%
root = 'BCN_20k_test/BCN_20k_train'
dataset = ImageFolder(root=root, transform=transform)
print(f"Classes found: {dataset.classes}")   # prints your disease names
print(f"Total images:  {len(dataset)}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 root = 'BCN_20k_test/BCN_20k_train'
# ----> 2 dataset = ImageFolder(root=root, transform=transform)
#       3 print(f"Classes found: {dataset.classes}")   # prints your disease names
#       4 print(f"Total images:  {len(dataset)}")
#
# NameError: name 'ImageFolder' is not defined
